# %%
lambda = 5
x = rexp(10000, lambda)
hist(x, freq=FALSE)

# %%
mean(x)
# Out:
# [1] 0.2013419

# %%
1/5.0
# Out:
# [1] 0.2

# %%
var(x)
# Out:
# [1] 0.03933554

# %%
1/(5.0^2)
# Out:
# [1] 0.04

# %%
lambda = 1
x = rexp(10000, lambda)
hist(x, freq=FALSE)

# %%
mean(x)
# Out:
# [1] 1.009827

# %%
var(x)
# Out:
# [1] 1.018877
