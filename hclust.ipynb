# %% [markdown]
# 階層的クラスタリング

# %%
# Example of Hierachical Clustering
#
# read seiseki data
seiseki <- read.table("table9.1.txt",header=TRUE)

# compute piar-wize distances
D <- dist(seiseki)

# hierachical clustering
hc <- hclust(D, method ="ward.D")

# plot the dendro-gram
plot(hc)
# Out:
# Plot with title “Cluster Dendrogram”
